# %%
print("Hello World")
# Out:
# Hello World

# %%
2+4
# Out:
# 6

# %%
2*4
# Out:
# 8

# %%
2**3
# Out:
# 8

# %%
#Variable declaring
name = 'Dibyaranjan Jena'

# %%
print(name)
# Out:
# Dibyaranjan Jena

# %%
lier = True #Remeber to use upper case True

# %%
print(lier)
# Out:
# True

# %%
12 % 2
# Out:
# 0

# %%
12 % 5
# Out:
# 2

# %% [markdown]
# For info use the below math function

# %% [markdown]
# https://docs.python.org/3/library/math.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math

# %%
math.sin(12)
# Out:
# -0.5365729180004349
